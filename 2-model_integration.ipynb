# %% [markdown]
# ## Models Integration with OpenAI , Google Gemini and GROQ

# %%
import os
from dotenv import load_dotenv
load_dotenv()

google_api_key = os.getenv("GOOGLE_API_KEY") or os.getenv("GOOGLE_GENAI_API_KEY")
if google_api_key:
    os.environ["GOOGLE_API_KEY"] = google_api_key

groq_api_key = os.getenv("GROQ_API_KEY")
if groq_api_key:
    os.environ["GROQ_API_KEY"] = groq_api_key

# %%
from langchain.chat_models import init_chat_model
# choose a single model string (init_chat_model expects a string, not a list)
if groq_api_key:
    model = init_chat_model("llama-3.1-70b-versatile", model_provider="groq")
elif google_api_key:
    model = init_chat_model("gemini-1.5-pro", model_provider="google_genai")
else:
    raise RuntimeError("No API key available for Groq or Gemini")
model
# Out:
# ChatGroq(output_version=None, profile={}, client=<groq.resources.chat.completions.Completions object at 0x0000014B9EEE91F0>, async_client=<groq.resources.chat.completions.AsyncCompletions object at 0x0000014B9F02DB20>, model_name='llama-3.1-70b-versatile', model_kwargs={}, groq_api_key=SecretStr('**********'), groq_api_base=None, groq_proxy=None)

# %%
## invoke the model with simple prompt

if getattr(model, "model_name", "") == "llama-3.1-70b-versatile":
    model = init_chat_model("llama-3.3-70b-versatile", model_provider="groq")

response = model.invoke("Hello how are you?")
print(response)
# Out:
# content="Hello, I'm doing well, thank you for asking. I'm a large language model, so I don't have feelings or emotions like humans do, but I'm always happy to chat with you and help with any questions or topics you'd like to discuss. How about you, how's your day going?" additional_kwargs={} response_metadata={'token_usage': {'completion_tokens': 64, 'prompt_tokens': 40, 'total_tokens': 104, 'completion_time': 0.141529009, 'completion_tokens_details': None, 'prompt_time': 0.00301152, 'prompt_tokens_details': None, 'queue_time': 0.158387068, 'total_time': 0.144540529}, 'model_name': 'llama-3.3-70b-versatile', 'system_fingerprint': 'fp_3272ea2d91', 'service_tier': 'on_demand', 'finish_reason': 'stop', 'logprobs': None, 'model_provider': 'groq'} id='lc_run--019e7dca-28a6-7df3-95d5-e96aefa7d8a5-0' tool_calls=[] invalid_tool_calls=[] usage_metadata={'input_tokens': 40, 'output_tokens': 64, 'total_tokens': 104}

# %%
## to check only response
response.content
# Out:
# "Hello, I'm doing well, thank you for asking. I'm a large language model, so I don't have feelings or emotions like humans do, but I'm always happy to chat with you and help with any questions or topics you'd like to discuss. How about you, how's your day going?"

# %% [markdown]
# ## Google Gemini Model Integration

# %%
import os
from langchain.chat_models import init_chat_model
from dotenv import load_dotenv
load_dotenv()

google_api_key = os.getenv("GOOGLE_API_KEY") or os.getenv("GOOGLE_GENAI_API_KEY")
if google_api_key:
    os.environ["GOOGLE_API_KEY"] = google_api_key

model = init_chat_model("google_genai:gemini-2.5-flash-lite")
response = model.invoke("Why do parrots talk?")
response.content
# Out:
# 'Parrots talk primarily because of their **remarkable vocal learning abilities**, which are far more advanced than in most other bird species, and often even other animals. This ability is driven by a combination of biological, social, and cognitive factors.\n\nHere\'s a breakdown of the key reasons:\n\n**1. Biological and Neurological Basis: Vocal Learning**\n\n*   **Specialized Brain Structures:** Parrots have unique brain structures that are dedicated to vocal learning and production. The most prominent is the **"song system"**, which is more complex in parrots than in many other songbirds. This system includes areas like the "high vocal center" (HVC) and the "nucleus of the anterior commissure" (RA), which are highly developed in parrots and play a crucial role in learning and mimicking sounds.\n*   **Syringeal Anatomy:** The syrinx, the vocal organ of birds, is also adapted for complex sound production in parrots.\n\n**2. Social Bonding and Communication**\n\n*   **Flock Behavior:** In the wild, parrots are highly social animals that live in flocks. Vocalizations are essential for maintaining group cohesion, identifying individuals, coordinating foraging, warning of predators, and establishing social hierarchies.\n*   **Mimicry as a Social Tool:** The ability to mimic sounds, including the calls of other parrots and even other animals, likely evolved as a way to better integrate into the flock and communicate effectively within their social group. By mimicking the sounds of their companions, they can signal belonging and build stronger social bonds.\n\n**3. Cognitive Abilities and Intelligence**\n\n*   **Problem-Solving and Tool Use:** Parrots are known for their high intelligence, often exhibiting problem-solving skills, the ability to understand cause and effect, and even tool use in some cases. This cognitive capacity supports their ability to learn and apply vocalizations meaningfully.\n*   **Understanding Context:** While it might seem like random mimicry, many parrots demonstrate an understanding of the context in which words and phrases are used. They can learn to associate specific sounds with specific objects, actions, or even emotions. For example, a parrot might say "hello" when someone enters the room or "goodbye" when they leave.\n\n**4. Seeking Attention and Interaction**\n\n*   **Social Rewards:** In captivity, parrots often learn to "talk" because it elicits a positive response from their human caregivers. When they make a sound that their owner finds pleasing or exciting, they receive attention, praise, or even treats. This social reward reinforces the behavior, encouraging them to repeat it.\n*   ** Boredom and Stimulation:** For intelligent and social creatures like parrots, boredom can be a significant issue. Vocalizing can be a way for them to entertain themselves, seek stimulation, and engage with their environment.\n\n**5. Learning and Imitation**\n\n*   **Observational Learning:** Parrots are excellent observers and learners. They are naturally inclined to imitate sounds they hear frequently in their environment, especially those made by their flock mates (which, in a pet setting, are their human family).\n*   **Repetition and Practice:** Like any skill, vocal learning requires practice. Parrots will often repeat sounds and words they hear until they get them right and receive the desired social reinforcement.\n\n**In summary, parrots talk because:**\n\n*   **They are biologically equipped for vocal learning.**\n*   **It\'s a crucial part of their social behavior in the wild.**\n*   **Their intelligence allows them to learn and associate sounds with context.**\n*   **In captivity, they learn that talking gets them attention and interaction.**\n\nIt\'s important to remember that not all parrots "talk" in the human sense of having conversations. Some species are more prone to vocal mimicry than others, and individual parrots will vary in their ability and willingness to learn words. However, the fund ...

# %%
import os
from langchain_google_genai import ChatGoogleGenerativeAI

model = ChatGoogleGenerativeAI(model = "gemini-2.5-flash-lite")

# question for the model and get the reponse
response = model.invoke("How much water an elephant drint in a day?")
response.content
# Out:
# "An adult elephant can drink a remarkable amount of water in a single day. The typical range is **between 30 and 50 gallons (approximately 115 to 190 liters)**.\n\nHowever, this can vary significantly depending on several factors:\n\n*   **Temperature and Heat:** During hot weather, elephants will drink much more to stay hydrated and cool down.\n*   **Activity Level:** If an elephant is more active, it will need more water.\n*   **Diet:** Elephants that eat a lot of dry vegetation will need to drink more to compensate for the lack of moisture in their food.\n*   **Size of the Elephant:** Larger elephants naturally require more water.\n*   **Availability of Water:** If water sources are scarce, they may drink a large amount when they find it, even if it's more than they'd typically need for that day.\n\nIn extreme conditions, some elephants have been known to drink even more than 50 gallons."

# %% [markdown]
# ## GROQ model integration

# %%
import os
from langchain.chat_models import init_chat_model
from dotenv import load_dotenv
load_dotenv()

groq_api_key = os.getenv("GROQ_API_KEY")
if groq_api_key:
    os.environ["GROQ_API_KEY"] = groq_api_key

model = init_chat_model("groq:llama-3.3-70b-versatile")
response = model.invoke("What is network in cs")
response.content
# Out:
# '**Network in Computer Science**\n=====================================\n\nA network in computer science refers to a collection of interconnected devices, such as computers, servers, and other hardware components, that communicate with each other to share resources, exchange data, and provide services. These devices are connected using physical or wireless links, such as cables, Wi-Fi, or Ethernet, and communicate using standardized protocols.\n\n**Types of Networks**\n--------------------\n\n1. **Local Area Network (LAN)**: A LAN connects devices within a limited geographical area, such as a home, office building, or campus.\n2. **Wide Area Network (WAN)**: A WAN connects devices over a larger geographical area, such as a city or country.\n3. **Wireless Network (WLAN)**: A WLAN connects devices wirelessly using radio waves.\n4. ** Metropolitan Area Network (MAN)**: A MAN connects devices within a metropolitan area, such as a city or town.\n5. **Virtual Private Network (VPN)**: A VPN connects devices over a public network, such as the internet, using encryption and tunneling protocols.\n\n**Network Topology**\n-------------------\n\nNetwork topology refers to the physical or logical arrangement of devices in a network. Common network topologies include:\n\n1. **Star Topology**: Devices are connected to a central hub or switch.\n2. **Bus Topology**: Devices are connected to a single cable or backbone.\n3. **Ring Topology**: Devices are connected in a circular configuration.\n4. **Mesh Topology**: Each device is connected to every other device.\n\n**Network Protocols**\n--------------------\n\nNetwork protocols are standardized rules that govern communication between devices in a network. Common network protocols include:\n\n1. **TCP/IP (Transmission Control Protocol/Internet Protocol)**: A suite of protocols that govern communication over the internet.\n2. **HTTP (Hypertext Transfer Protocol)**: A protocol that governs communication between web servers and clients.\n3. **FTP (File Transfer Protocol)**: A protocol that governs file transfer between devices.\n4. **DNS (Domain Name System)**: A protocol that governs domain name resolution.\n\n**Network Devices**\n------------------\n\nCommon network devices include:\n\n1. **Routers**: Devices that connect multiple networks and route traffic between them.\n2. **Switches**: Devices that connect multiple devices within a network and forward traffic between them.\n3. **Hubs**: Devices that connect multiple devices within a network and broadcast traffic to all connected devices.\n4. **Modems**: Devices that connect a network to a wider area network or the internet.\n\n**Network Security**\n------------------\n\nNetwork security refers to the measures taken to protect a network from unauthorized access, use, or damage. Common network security measures include:\n\n1. **Firewalls**: Devices or software that block unauthorized traffic from entering a network.\n2. **Encryption**: The process of converting plaintext data into unreadable ciphertext to protect it from interception.\n3. **Authentication**: The process of verifying the identity of devices or users before granting access to a network.\n4. **Access Control**: The process of controlling who can access a network and what resources they can access.'

# %%
import os
from langchain_groq import ChatGroq

model = init_chat_model("groq:llama-3.3-70b-versatile")
response = model.invoke("How much an elephant drink water in a day?")
response.content
# Out:
# "An adult elephant can drink a significant amount of water in a day, typically ranging from 30 to 50 gallons (136 to 190 liters) per day, depending on factors such as climate, activity level, and access to water. However, in hot climates or during periods of intense physical activity, an elephant's water intake can increase to as much as 70-80 gallons (265-303 liters) per day.\n\nIt's worth noting that elephants need access to large amounts of water not only for drinking but also for bathing and cooling themselves, as they can lose a significant amount of water through their skin and respiratory system."

# %% [markdown]
# ## Streaming and Batch
#
# ### Streaming
# Most model can stream their output content while it is being generated. By displaying output progressively, streaming significantly improves user experience particularly for longer reponses. Calling stream() returns an iterator an interator that yields output chunks as they are produced. You can use a loop to process each chunk in real-time.

# %%
model.invoke("Write a 200 word essay on the history of the internet")
# Out:
# AIMessage(content="The history of the internet dates back to the 1960s, when the United States Department of Defense's Advanced Research Projects Agency (ARPA) funded a project to create a network of computers that could communicate with each other. This project, called ARPANET, was the first operational packet switching network, and it was developed in the late 1960s and early 1970s. In the 1980s, the Internet Protocol (IP) was developed, allowing different computer networks to communicate with each other and forming the modern internet. \n\nThe World Wide Web (WWW) was invented in 1989 by Tim Berners-Lee, making it easy for people to access and share information using web browsers and hyperlinks. The internet became widely available to the public in the 1990s, with the development of internet service providers (ISPs) and web browsers like Netscape and Internet Explorer. Since then, the internet has grown exponentially, with the widespread adoption of broadband, mobile devices, and social media. Today, the internet is an essential part of modern life, used for communication, entertainment, education, and commerce. Its impact on society has been profound, revolutionizing the way we live, work, and interact with each other.", additional_kwargs={}, response_metadata={'token_usage': {'completion_tokens': 255, 'prompt_tokens': 47, 'total_tokens': 302, 'completion_time': 0.492755639, 'completion_tokens_details': None, 'prompt_time': 0.001668402, 'prompt_tokens_details': None, 'queue_time': 0.157776078, 'total_time': 0.494424041}, 'model_name': 'llama-3.3-70b-versatile', 'system_fingerprint': 'fp_45180df409', 'service_tier': 'on_demand', 'finish_reason': 'stop', 'logprobs': None, 'model_provider': 'groq'}, id='lc_run--019e7dcf-26ff-7af0-875a-963a0ed3d400-0', tool_calls=[], invalid_tool_calls=[], usage_metadata={'input_tokens': 47, 'output_tokens': 255, 'total_tokens': 302})

# %%
for chunk in model.stream("Write a 200 word essay on the history of the internet"):
    print(chunk.content, end = "", flush=True)

# by using the stream method you can see the output will its generated instead of waiting for the whole response to be generated and then printing it.
# Out:
# The history of the internet dates back to the 1960s, when the United States Department of Defense's Advanced Research Projects Agency (ARPA) funded a project to create a network of computers that could communicate with each other. This project, called ARPANET, was the first operational packet switching network, and it was developed in the late 1960s and early 1970s. In the 1980s, the Internet Protocol (IP) was developed, allowing different computer networks to communicate with each other and forming the modern internet. The World Wide Web (WWW) was invented in 1989 by Tim Berners-Lee, making it easy for people to access and share information using web browsers and hyperlinks. The internet was opened to commercial use in the 1990s, and it has since become an essential part of modern life, revolutionizing the way people communicate, work, and access information. Today, the internet is a global network of billions of interconnected devices, and it continues to shape and transform society in profound ways. The internet's impact on modern society has been immense, and its continued evolution will likely have a significant impact on the future. Its growth and development show no signs of slowing down.

# %%
model.invoke("Write a 200 word essay on the history of the internet")
# Out:
# AIMessage(content="The history of the internet dates back to the 1960s, when the United States Department of Defense's Advanced Research Projects Agency (ARPA) funded a project to create a network of computers that could communicate with each other. This project, called ARPANET, was the first operational packet switching network, and it was developed in the late 1960s and early 1970s. In the 1980s, the Internet Protocol (IP) was developed, allowing different computer networks to communicate with each other and forming the modern internet. The World Wide Web (WWW) was invented in 1989 by Tim Berners-Lee, making it easy for people to access and share information using web browsers and hyperlinks. The internet was initially only available to government and academic institutions, but it was opened to the public in the 1990s. Since then, the internet has grown rapidly, with the widespread adoption of broadband internet, social media, and e-commerce. Today, the internet is an essential part of modern life, connecting billions of people around the world and transforming the way we communicate, work, and access information. The internet's impact on society has been profound, and its continued evolution will likely shape the future of humanity.", additional_kwargs={}, response_metadata={'token_usage': {'completion_tokens': 253, 'prompt_tokens': 47, 'total_tokens': 300, 'completion_time': 0.621420834, 'completion_tokens_details': None, 'prompt_time': 0.002259579, 'prompt_tokens_details': None, 'queue_time': 0.16154115, 'total_time': 0.623680413}, 'model_name': 'llama-3.3-70b-versatile', 'system_fingerprint': 'fp_45180df409', 'service_tier': 'on_demand', 'finish_reason': 'stop', 'logprobs': None, 'model_provider': 'groq'}, id='lc_run--019e7dd5-ef87-79b1-97a6-bc6de4948728-0', tool_calls=[], invalid_tool_calls=[], usage_metadata={'input_tokens': 47, 'output_tokens': 253, 'total_tokens': 300})

# %% [markdown]
# ## Batch
# Batching a collection of independent request to a model can significantly improve performance and reduce costs, as the processing can be done in parallel.

# %%
response = model.batch([
    "Why do parrots talk?",
    "How much water an elephant drink in a day?"
])
for resp in response:
    print(resp.content)
# Out:
# Parrots are known for their ability to mimic human speech and other sounds, but why do they do it? There are several theories:
#
# 1. **Communication and social bonding**: In the wild, parrots use vocalizations to communicate with each other, especially with their flock members. They may mimic sounds to establish social bonds, reinforce relationships, or even to attract a mate. By mimicking human speech, parrots may be attempting to connect with their human caregivers and form a similar bond.
# 2. **Learning and problem-solving**: Parrots are highly intelligent birds, and mimicking sounds can be a form of cognitive exercise for them. They may learn to associate certain sounds or phrases with food, attention, or other rewards, which can motivate them to continue vocalizing.
# 3. **Attention-seeking**: Parrots are social animals and thrive on interaction. By talking or mimicking sounds, they may be seeking attention from their human caregivers, which can lead to rewards, such as treats or playtime.
# 4. **Emotional expression**: Parrots may use vocalizations to express emotions like happiness, excitement, or stress. They may mimic sounds or phrases that they associate with positive or negative experiences, such as a happy phrase when they see their owner or a distressed call when they're left alone.
# 5. **Instinctual behavior**: In the wild, parrots use vocalizations to warn other birds of potential threats or to signal the location of food. Domesticated parrots may retain these instinctual behaviors and mimic sounds as a way to alert their human caregivers to potential dangers or to request food.
# 6. **Brain development**: Research suggests that parrots' brains are wired to process and mimic complex sounds, which may be an evolutionary adaptation to help them communicate with other birds. This ability to mimic sounds may be an innate trait that is expressed in domesticated parrots as well.
#
# It's likely that parrots talk for a combination of these reasons, and individual birds may have their own motivations and preferences. By understanding why parrots talk, owners can better respond to their birds' needs and provide a stimulating and engaging environment that encourages healthy vocalization.
# An elephant's water consumption can vary depending on several factors, such as its size, age, climate, and level of activity. However, on average, an adult elephant can drink around 30-50 gallons (136-189 liters) of water per day.
#
# In hot climates, elephants may drink even more water to stay hydrated, with some estimates suggesting they can consume up to 100 gallons (378 liters) of water per day. Baby elephants, on the other hand, may drink around 5-10 gallons (19-38 liters) of water per day.
#
# It's worth noting that elephants also get some of their water intake from the food they eat, such as fruits, leaves, and bark, which can contain a significant amount of water. However, they still need to drink a significant amount of water to stay hydrated, especially in hot and dry climates.

# %%
# tools.
